# %% [markdown]
# # Handling missing values

# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv')
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline              Health       2006   $13,343,330
# 6   7          Cityace              Health       2010   $14,373,383
# 7   8   Kayelectronics              Health       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627     7%
# 3   7429377 Dollars   8427816    26%
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv')
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline                 NaN       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics                 NaN       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627    NaN
# 3   7429377 Dollars   8427816    26%
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv')
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline                 NaN       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics                 NaN       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627    NaN
# 3   7429377 Dollars   8427816    26%
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv')
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline                 NaN       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics                 NaN       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit          Growth
# 0   6482465 Dollars   5274553            30%
# 1    916455 Dollars   3005820            20%
# 2   7591189 Dollars   3138627  not available
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv',na_values = 'not available')
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline                 NaN       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics                 NaN       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627    NaN
# 3   7429377 Dollars   8427816    26%
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv')
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline                 NaN       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics           no values       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit          Growth
# 0   6482465 Dollars   5274553            30%
# 1    916455 Dollars   3005820            20%
# 2   7591189 Dollars   3138627  not available
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv',na_values = ['not available','no values'])
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline                 NaN       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics                 NaN       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627    NaN
# 3   7429377 Dollars   8427816    26%
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv',na_values ={'Industry':'no values','Growth': 'not available'})
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline                 NaN       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics                 NaN       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627    NaN
# 3   7429377 Dollars   8427816    26%
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv')
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline                 NaN       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics                Null       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627   Null
# 3   7429377 Dollars   8427816    26%
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv')
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline                 NaN       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics                 NaN       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627   Null
# 3   7429377 Dollars   8427816    26%
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv',keep_default_na = True)
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline                 NaN       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics                 NaN       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627   Null
# 3   7429377 Dollars   8427816    26%
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv')
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline              Health       2006   $13,343,330
# 6   7          Cityace              Health       2010   $14,373,383
# 7   8   Kayelectronics              Health       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627    60%
# 3   7429377 Dollars   8427816    26%
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv',na_filter = False)
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline              Health       2006   $13,343,330
# 6   7          Cityace              Health       2010   $14,373,383
# 7   8   Kayelectronics              Health       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627    60%
# 3   7429377 Dollars   8427816    26%
# ...

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv')
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline              Health       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics              Health       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627    NaN
# 3   7429377 Dollars   8427816    NaN
# ...

# %%
df.isnull()
# Out:
#       ID   Name  Industry  Inception  Revenue  Expenses  Profit   Growth
# 0  False  False     False      False    False     False    False   False
# 1  False  False     False      False    False     False    False   False
# 2  False  False     False      False    False     False    False    True
# 3  False  False     False      False    False     False    False    True
# 4  False  False     False      False    False     False    False    True
# 5  False  False     False      False    False     False    False    True
# 6  False  False      True      False    False     False    False   False
# 7  False  False     False      False    False     False    False   False
# 8  False  False     False      False    False     False    False   False
# 9  False  False     False      False    False     False    False   False

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv')
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline              Health       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics              Health       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627    NaN
# 3   7429377 Dollars   8427816    NaN
# ...

# %%
df.isnull()
# Out:
#       ID   Name  Industry  Inception  Revenue  Expenses  Profit   Growth
# 0  False  False     False      False    False     False    False   False
# 1  False  False     False      False    False     False    False   False
# 2  False  False     False      False    False     False    False    True
# 3  False  False     False      False    False     False    False    True
# 4  False  False     False      False    False     False    False    True
# 5  False  False     False      False    False     False    False    True
# 6  False  False      True      False    False     False    False   False
# 7  False  False     False      False    False     False    False   False
# 8  False  False     False      False    False     False    False   False
# 9  False  False     False      False    False     False    False   False

# %%
df.isnull().sum()  #how many null value present in column
# Out:
# ID           0
# Name         0
# Industry     1
# Inception    0
# Revenue      0
# Expenses     0
# Profit       0
# Growth       4
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 5

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_10.csv')
df
# Out:
#    ID             Name            Industry  Inception        Revenue  \
# 0   1          Lamtone         IT Services       2009   $11,757,018
# 1   2        Stripfind  Financial Services       2010   $12,329,371
# 2   3  Canecorporation              Health       2012   $10,597,009
# 3   4         Mattouch         IT Services       2013   $14,026,934
# 4   5        Techdrill              Health       2009   $10,573,990
# 5   6         Techline              Health       2006   $13,343,330
# 6   7          Cityace                 NaN       2010   $14,373,383
# 7   8   Kayelectronics              Health       2009  $763,826,329
# 8   9          Ganzlax         IT Services       2011  $983,299,222
# 9  10      Trantraxlax      Govt. Services       2011   $11,088,336
#
#            Expenses   Profit  Growth
# 0   6482465 Dollars   5274553    30%
# 1    916455 Dollars   3005820    20%
# 2   7591189 Dollars   3138627    NaN
# 3   7429377 Dollars   8427816    NaN
# ...

# %%
df.notnull() #True value find
# Out:
#      ID  Name  Industry  Inception  Revenue  Expenses  Profit   Growth
# 0  True  True      True       True     True      True     True    True
# 1  True  True      True       True     True      True     True    True
# 2  True  True      True       True     True      True     True   False
# 3  True  True      True       True     True      True     True   False
# 4  True  True      True       True     True      True     True   False
# 5  True  True      True       True     True      True     True   False
# 6  True  True     False       True     True      True     True    True
# 7  True  True      True       True     True      True     True    True
# 8  True  True      True       True     True      True     True    True
# 9  True  True      True       True     True      True     True    True

# %%
df.notnull().sum()
# Out:
# ID           10
# Name         10
# Industry      9
# Inception    10
# Revenue      10
# Expenses     10
# Profit       10
# Growth        6
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 75

# %%
#series
import numpy as np
sr = pd.Series([1,2,3,np.nan,4,np.NAN])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %% [markdown]
# # Method of pandas

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_5.csv')
df
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47687393     7%
# 3   4              NaN         IT Services  23466467    NaN
# 4   5             Mark                 NaN   3545565    21%

# %%
df.dropna() #NaN ,NULL VALUE R ROW DROP KORE DE
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47687393     7%

# %%
df.dropna(axis = 1)
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  23648990
# 2   3  47687393
# 3   4  23466467
# 4   5   3545565

# %%
df.dropna(how = 'any')
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47687393     7%

# %%
df.dropna(axis=1, how = 'any')
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  23648990
# 2   3  47687393
# 3   4  23466467
# 4   5   3545565

# %%
df.dropna(how = 'all')
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47687393     7%
# 3   4              NaN         IT Services  23466467    NaN
# 4   5             Mark                 NaN   3545565    21%

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_5.csv')
df
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47687393     7%
# 3   4              NaN         IT Services  23466467    NaN
# 4   5             Mark                 NaN   3545565    21%

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_5.csv')
df
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47687393.0     7%
# 3  4.0              NaN         IT Services  23466467.0    NaN
# 4  NaN              NaN                 NaN         NaN    NaN

# %%
df.dropna(how = 'all')
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47687393.0     7%
# 3  4.0              NaN         IT Services  23466467.0    NaN

# %%
df.dropna(thresh =1)
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47687393.0     7%
# 3  4.0              NaN         IT Services  23466467.0    NaN

# %%
df.dropna(thresh =2)
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47687393.0     7%
# 3  4.0              NaN         IT Services  23466467.0    NaN

# %%
df.dropna(thresh =4)
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47687393.0     7%

# %%
df = pd.read_csv('D:\\Machine learning\\Fortune_5.csv')
df
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47687393.0     7%
# 3  4.0              NaN         IT Services  23466467.0    NaN
# 4  NaN              NaN                 NaN         NaN    NaN

# %%
df.dropna(subset = ['ID'])
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47687393.0     7%
# 3  4.0              NaN         IT Services  23466467.0    NaN

# %%
df.dropna(subset = ['Name'])
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47687393.0     7%

# %%
df.dropna(inplace = True)
df
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47687393.0     7%
